# %% [markdown]
# # Modelos de clasificación con datos numéricos, imágenes y mixto

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Copiamos los ficheros de GDrive al entorno de ejecución
# !cp /content/drive/My\ Drive/x_train_num.npy x_train_num.npy
# !cp /content/drive/My\ Drive/x_train_img.npy x_train_img.npy
# !cp /content/drive/My\ Drive/x_val_num.npy x_val_num.npy
# !cp /content/drive/My\ Drive/x_val_img.npy x_val_img.npy
# !cp /content/drive/My\ Drive/x_test_num.npy x_test_num.npy
# !cp /content/drive/My\ Drive/x_test_img.npy x_test_img.npy
# !cp /content/drive/My\ Drive/y_train_class.npy y_train_class.npy
# !cp /content/drive/My\ Drive/y_val_class.npy y_val_class.npy
# !cp /content/drive/My\ Drive/y_test_class.npy y_test_class.npy

# %%
# Cargamos los ficheros a variables de nuestro entorno
import numpy as np
x_train_num = np.load('x_train_num.npy')
x_train_img = np.load('x_train_img.npy')
x_val_num = np.load('x_val_num.npy')
x_val_img = np.load('x_val_img.npy')
x_test_num = np.load('x_test_num.npy')
x_test_img = np.load('x_test_img.npy')
y_train_class = np.load('y_train_class.npy')
y_val_class = np.load('y_val_class.npy')
y_test_class = np.load('y_test_class.npy')

# %%
# Mostramos la forma de los arrays para ver que no haya errores
print("datos numericos de train:", x_train_num.shape)
print("datos de imágenes de train:",x_train_img.shape)
print("etiquetas de train:",y_train_class.shape)
print("datos numericos de validación:",x_val_num.shape)
print("datos de imágenes de validación:",x_val_img.shape)
print("etiquetas de validación:",y_val_class.shape)
print("datos numericos de test:",x_test_num.shape)
print("datos de imágenes de test:",x_test_img.shape)
print("etiquetas de test:",y_test_class.shape)
# Out:
# datos numericos de train: (7125, 30)
# datos de imágenes de train: (7125, 64, 64, 3)
# etiquetas de train: (7125, 3)
# datos numericos de validación: (814, 30)
# datos de imágenes de validación: (814, 64, 64, 3)
# etiquetas de validación: (814, 3)
# datos numericos de test: (2687, 30)
# datos de imágenes de test: (2687, 64, 64, 3)
# etiquetas de test: (2687, 3)

# %% [markdown]
# ### Modelo de clasificación sólo con datos numéricos

# %% [markdown]
# Creamos un modelo secuencial con una primera capa densa con 8 neuronas. En esa primera capa hay que pasar la dimensión y la función de activación es relu. La siguiente capa que añadimos ya es más pequeña con 4 neuronas y también función de activación relu. La última capa al ser una red para clasificación tiene tantas neuronas como grupos hay, es decir, 3. Y su función de activación es softmax.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(Dense(8, input_dim=x_train_num.shape[1], activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(3, activation="softmax"))

# %% [markdown]
# Vamos a usar el optimizador Adam y la función de pérdidas la crossentropía.

# %%
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
# train the model
print("[INFO] training model...")
model.fit(x=x_train_num, y=y_train_class, 
	validation_data=(x_val_num, y_val_class),
	epochs=50, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/50
# 891/891 [==============================] - 3s 4ms/step - loss: 5.9831 - accuracy: 0.3864 - val_loss: 1.0927 - val_accuracy: 0.4410
# Epoch 2/50
# 891/891 [==============================] - 3s 3ms/step - loss: 1.0789 - accuracy: 0.4087 - val_loss: 1.0851 - val_accuracy: 0.4373
# 891/891 [==============================] - 3s 3ms/step - loss: 0.6229 - accuracy: 0.7481 - val_loss: 0.5959 - val_accuracy: 0.7776
# Epoch 44/50
# 891/891 [==============================] - 3s 3ms/step - loss: 0.6199 - accuracy: 0.7464 - val_loss: 0.5884 - val_accuracy: 0.7764
# Epoch 45/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6230 - accuracy: 0.7450 - val_loss: 0.5975 - val_accuracy: 0.7469
# Epoch 46/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6214 - accuracy: 0.7474 - val_loss: 0.5999 - val_accuracy: 0.7457
# Epoch 47/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6199 - accuracy: 0.7474 - val_loss: 0.6919 - val_accuracy: 0.6781
# Epoch 48/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6384 - accuracy: 0.7364 - val_loss: 0.6051 - val_accuracy: 0.7531
# Epoch 49/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6206 - accuracy: 0.7488 - val_loss: 0.6078 - val_accuracy: 0.7617
# Epoch 50/50
# 891/891 [==============================] - 3s 4ms/step - loss: 0.6174 - accuracy: 0.7513 - val_loss: 0.5856 - val_accuracy: 0.7801

# %% [markdown]
# Comprobamos el modelo con los datos de test.

# %%
scores = model.evaluate(x_test_num, y_test_class, verbose=0)
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Loss: 0.602
# Accuracy: 0.757

# %% [markdown]
# ### Modelo de clasificación sólo con imágenes

# %% [markdown]
# En esta ocación usaremos una red neuronal convolucional para poder trabajar con las imágenes. Crearemos el modelo mediante un método funcional en vez de secuencial como anteriormente. Dependiendo de los filtros que pasemos creará diferentes capas, en este caso crearemos una de 16, otra de 32 y otra de 64. En la primera iteración indicamos la dimensión de los datos al igual que hacíamos en el modelo secuencial.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, Input
# Tamaño de las imágenes
inputShape = (64, 64, 3)
chanDim = -1
# Filtros que vamos a aplicar en las capas convolucionales
filters=(16, 32, 64)
inputs = Input(shape=inputShape)
# Recorremos el bucle creando las diferentes capas
for (i, f) in enumerate(filters):
		# si es la primera capa indicamos el inputshape
  if i == 0:
	  x = inputs
	# CONV => BN => RELU => POOL
  x = Conv2D(f, (3, 3), padding="same")(x)
  x = BatchNormalization(axis=chanDim)(x)
  x = Activation("relu")(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)
	
# Aplanamos los datos y ponemos una capa densa de 16 neuronas con activación relu
x = Flatten()(x)
x = Dense(16)(x)
x = BatchNormalization(axis=chanDim)(x)
x = Activation("relu")(x)
x = Dropout(0.5)(x)
# Añadimos otra capa densa de 4 neuronas y activación relu
x = Dense(4)(x)
x = Activation("relu")(x)
# Añadimos la última capa con 3 neuronas y función softmax para la calsificación 
x = Dense(3, activation="softmax")(x)
# Construimos la red neuronal
model = Model(inputs, x)

# %% [markdown]
# Vamos a usar el optimizador Adam y la función de pérdidas la crossentropía.

# %%
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])
# entrenamos el modelo
print("[INFO] training model...")
model.fit(x=x_train_img, y=y_train_class, 
    validation_data=(x_val_img, y_val_class),
    epochs=50, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0719 - accuracy: 0.4209 - val_loss: 1.1054 - val_accuracy: 0.3354
# Epoch 2/50
# 891/891 [==============================] - 7s 8ms/step - loss: 1.0422 - accuracy: 0.4521 - val_loss: 1.0268 - val_accuracy: 0.4779
# Epoch 3/50
# 891/891 [==============================] - 7s 8ms/step - loss: 1.0259 - accuracy: 0.4643 - val_loss: 1.0192 - val_accuracy: 0.4681
# Epoch 4/50
# 891/891 [==============================] - 7s 8ms/step - loss: 1.0115 - accuracy: 0.4741 - val_loss: 1.0470 - val_accuracy: 0.4644
# Epoch 5/50
# 891/891 [==============================] - 7s 8ms/step - loss: 1.0115 - accuracy: 0.4813 - val_loss: 1.0653 - val_accuracy: 0.4459
# Epoch 6/50
# 891/891 [==============================] - 7s 8ms/step - loss: 1.0016 - accuracy: 0.4859 - val_loss: 1.1027 - val_accuracy: 0.4607
# Epoch 7/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9913 - accuracy: 0.4900 - val_loss: 1.0111 - val_accuracy: 0.4742
# Epoch 8/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9864 - accuracy: 0.5008 - val_loss: 1.0907 - val_accuracy: 0.4754
# Epoch 9/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9747 - accuracy: 0.5040 - val_loss: 1.0445 - val_accuracy: 0.4803
# Epoch 10/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9636 - accuracy: 0.5133 - val_loss: 1.0915 - val_accuracy: 0.4644
# Epoch 11/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9496 - accuracy: 0.5267 - val_loss: 1.0572 - val_accuracy: 0.4730
# Epoch 12/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9345 - accuracy: 0.5349 - val_loss: 1.1055 - val_accuracy: 0.4509
# Epoch 13/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9187 - accuracy: 0.5418 - val_loss: 1.0474 - val_accuracy: 0.4619
# Epoch 14/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.9020 - accuracy: 0.5537 - val_loss: 1.0171 - val_accuracy: 0.5086
# Epoch 15/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.8773 - accuracy: 0.5666 - val_loss: 1.1804 - val_accuracy: 0.4361
# Epoch 16/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.8625 - accuracy: 0.5795 - val_loss: 1.1067 - val_accuracy: 0.4816
# Epoch 17/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.8313 - accuracy: 0.5899 - val_loss: 1.2017 - val_accuracy: 0.4472
# Epoch 18/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.8183 - accuracy: 0.6090 - val_loss: 1.1527 - val_accuracy: 0.4767
# Epoch 19/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.7930 - accuracy: 0.6279 - val_loss: 1.1494 - val_accuracy: 0.4840
# Epoch 20/50
# Epoch 41/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4708 - accuracy: 0.8031 - val_loss: 1.9513 - val_accuracy: 0.4509
# Epoch 42/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.5029 - accuracy: 0.7912 - val_loss: 1.8648 - val_accuracy: 0.4644
# Epoch 43/50
# 891/891 [==============================] - 8s 8ms/step - loss: 0.4836 - accuracy: 0.8041 - val_loss: 2.1159 - val_accuracy: 0.4545
# Epoch 44/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4883 - accuracy: 0.7993 - val_loss: 1.9965 - val_accuracy: 0.4717
# Epoch 45/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4651 - accuracy: 0.8095 - val_loss: 1.9199 - val_accuracy: 0.4705
# Epoch 46/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4733 - accuracy: 0.8031 - val_loss: 2.2669 - val_accuracy: 0.4595
# Epoch 47/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4755 - accuracy: 0.8044 - val_loss: 2.0398 - val_accuracy: 0.4386
# Epoch 48/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4386 - accuracy: 0.8192 - val_loss: 2.2060 - val_accuracy: 0.4459
# Epoch 49/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4277 - accuracy: 0.8233 - val_loss: 2.1166 - val_accuracy: 0.4337
# Epoch 50/50
# 891/891 [==============================] - 7s 8ms/step - loss: 0.4369 - accuracy: 0.8248 - val_loss: 2.2198 - val_accuracy: 0.4398

# %% [markdown]
# Comprobamos el modelo con los datos de test.

# %%
scores = model.evaluate(x_test_img, y_test_class, verbose=0)
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Loss: 1.974
# Accuracy: 0.469

# %% [markdown]
# ### Modelo de clasificación sólo con datos mixtos, imágenes y numéricos.

# %% [markdown]
# En esta ocasión usaremos los dos tipos de datos que hemos visto anteriormente. Vamos a crear un modelo con dos ramas:
#
#
# 1.   Rama 1: una red neuronal para analizar los datos numéricos, exactamente igual a la que hemos usado antes, pero sin la capa final de clasificación.
# 2.   Rama 2: una red neuronal convolucional para trabajar con las imágenes, exactamente igual a la anterior, pero sin la capa final de clasificación.
#
# Posteriormente combinaremos ambas ramas creando otra capa densa de 4 neuronas con función de activación relu y la capa final de clasificación con 3 neuronas y función de activación softmax.

# %%
# Creamos la rama numérica
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

mlp = Sequential()
mlp.add(Dense(8, input_dim=x_train_num.shape[1], activation="relu"))
mlp.add(Dense(4, activation="relu"))

# %%
# Creamos la rama que trabaja con imágenes
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Dropout, Dense, Flatten, Input
# Tamaño de las imágenes
inputShape = (64, 64, 3)
chanDim = -1
# Filtros que vamos a aplicar en las capas convolucionales
filters=(16, 32, 64)
inputs = Input(shape=inputShape)
# Recorremos el bucle creando las diferentes capas
for (i, f) in enumerate(filters):
		# si es la primera capa indicamos el inputshape
  if i == 0:
	  x = inputs
	# CONV => BN => RELU => POOL
  x = Conv2D(f, (3, 3), padding="same")(x)
  x = BatchNormalization(axis=chanDim)(x)
  x = Activation("relu")(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)
	
# Aplanamos los datos y ponemos una capa densa de 16 neuronas con activación relu
x = Flatten()(x)
x = Dense(16)(x)
x = BatchNormalization(axis=chanDim)(x)
x = Activation("relu")(x)
x = Dropout(0.5)(x)
# Añadimos otra capa densa de 4 neuronas y activación relu
x = Dense(4)(x)
x = Activation("relu")(x)
# Construimos la red neuronal
cnn = Model(inputs, x)

# %%
from tensorflow.keras.layers import concatenate
# Combinamos ambas redes
combinedInput = concatenate([mlp.output, cnn.output])

# %%
# Añadimos la capa densa con 4 neuronas y la de 3 para la clasificación
x = Dense(4, activation="relu")(combinedInput)
x = Dense(3, activation="softmax")(x)

# %%
# Construimos el modelo que combina datos numéricos e imágenes
model = Model(inputs=[mlp.input, cnn.input], outputs=x)

# %%
# Usamos de nuevo el optimizados Adam y la función de pérdidas crossentropía y compilamos el modelo
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy'])

# %%
# Entrenamos el modelo
print("[INFO] training model...")
model.fit(
	x=[x_train_num, x_train_img], y=y_train_class,
	validation_data=([x_val_num, x_val_img], y_val_class),
	epochs=50, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.6955 - accuracy: 0.3641 - val_loss: 1.0795 - val_accuracy: 0.4459
# Epoch 2/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0763 - accuracy: 0.4146 - val_loss: 1.0763 - val_accuracy: 0.4459
# Epoch 3/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0687 - accuracy: 0.4225 - val_loss: 1.0312 - val_accuracy: 0.5135
# Epoch 4/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0890 - accuracy: 0.4469 - val_loss: 1.0650 - val_accuracy: 0.4619
# Epoch 5/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0607 - accuracy: 0.4389 - val_loss: 1.0618 - val_accuracy: 0.4631
# Epoch 6/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0534 - accuracy: 0.4484 - val_loss: 1.0567 - val_accuracy: 0.4754
# Epoch 7/50
# 891/891 [==============================] - 8s 9ms/step - loss: 1.0443 - accuracy: 0.4578 - val_loss: 1.0403 - val_accuracy: 0.4840
# Epoch 8/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.8989 - accuracy: 0.5437 - val_loss: 0.8045 - val_accuracy: 0.6278
# Epoch 9/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.7893 - accuracy: 0.6479 - val_loss: 0.7429 - val_accuracy: 0.6302
# Epoch 10/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.7426 - accuracy: 0.6588 - val_loss: 0.6675 - val_accuracy: 0.7224
# Epoch 11/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.7764 - accuracy: 0.6918 - val_loss: 1.0741 - val_accuracy: 0.4816
# Epoch 12/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.8681 - accuracy: 0.5416 - val_loss: 0.7790 - val_accuracy: 0.7199
# Epoch 13/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.7204 - accuracy: 0.7373 - val_loss: 0.6694 - val_accuracy: 0.7568
# Epoch 14/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6689 - accuracy: 0.7429 - val_loss: 0.6240 - val_accuracy: 0.7654
# Epoch 15/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6457 - accuracy: 0.7441 - val_loss: 0.7090 - val_accuracy: 0.7088
# Epoch 16/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6327 - accuracy: 0.7453 - val_loss: 0.7389 - val_accuracy: 0.6855
# Epoch 17/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6213 - accuracy: 0.7499 - val_loss: 0.6078 - val_accuracy: 0.7445
# Epoch 18/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6229 - accuracy: 0.7500 - val_loss: 0.5850 - val_accuracy: 0.7690
# Epoch 19/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6520 - accuracy: 0.7418 - val_loss: 0.5900 - val_accuracy: 0.7715
# Epoch 20/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6008 - accuracy: 0.7541 - val_loss: 0.6418 - val_accuracy: 0.7322
# Epoch 21/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5908 - accuracy: 0.7615 - val_loss: 0.5860 - val_accuracy: 0.7740
# Epoch 22/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6043 - accuracy: 0.7592 - val_loss: 0.6039 - val_accuracy: 0.7469
# Epoch 23/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5865 - accuracy: 0.7606 - val_loss: 0.5745 - val_accuracy: 0.7678
# Epoch 24/50
# 891/891 [==============================] - 8s 8ms/step - loss: 0.7041 - accuracy: 0.7387 - val_loss: 0.6332 - val_accuracy: 0.7248
# Epoch 25/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6232 - accuracy: 0.7471 - val_loss: 0.5971 - val_accuracy: 0.7604
# Epoch 26/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.6098 - accuracy: 0.7549 - val_loss: 0.5956 - val_accuracy: 0.7666
# Epoch 27/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5974 - accuracy: 0.7608 - val_loss: 0.5846 - val_accuracy: 0.7604
# Epoch 28/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5750 - accuracy: 0.7646 - val_loss: 0.5914 - val_accuracy: 0.7531
# Epoch 29/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5586 - accuracy: 0.7724 - val_loss: 0.5851 - val_accuracy: 0.7568
# Epoch 30/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5421 - accuracy: 0.7794 - val_loss: 0.5747 - val_accuracy: 0.7850
# Epoch 31/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5453 - accuracy: 0.7813 - val_loss: 0.5863 - val_accuracy: 0.7813
# Epoch 32/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5201 - accuracy: 0.7927 - val_loss: 0.6529 - val_accuracy: 0.7555
# Epoch 33/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5101 - accuracy: 0.7917 - val_loss: 0.5882 - val_accuracy: 0.7813
# Epoch 34/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.5045 - accuracy: 0.8001 - val_loss: 0.6271 - val_accuracy: 0.7445
# Epoch 35/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4995 - accuracy: 0.7979 - val_loss: 0.6207 - val_accuracy: 0.7506
# Epoch 36/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4865 - accuracy: 0.8042 - val_loss: 0.6685 - val_accuracy: 0.7469
# Epoch 37/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4843 - accuracy: 0.8056 - val_loss: 0.6366 - val_accuracy: 0.7604
# Epoch 38/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4755 - accuracy: 0.8098 - val_loss: 0.6477 - val_accuracy: 0.7543
# Epoch 39/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4634 - accuracy: 0.8116 - val_loss: 0.6406 - val_accuracy: 0.7543
# Epoch 40/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4537 - accuracy: 0.8147 - val_loss: 0.6859 - val_accuracy: 0.7420
# Epoch 41/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4400 - accuracy: 0.8227 - val_loss: 0.7071 - val_accuracy: 0.7408
# Epoch 42/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4324 - accuracy: 0.8271 - val_loss: 0.6709 - val_accuracy: 0.7518
# Epoch 43/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4269 - accuracy: 0.8319 - val_loss: 0.6524 - val_accuracy: 0.7568
# Epoch 44/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4176 - accuracy: 0.8337 - val_loss: 0.7079 - val_accuracy: 0.7383
# Epoch 45/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4079 - accuracy: 0.8376 - val_loss: 0.7864 - val_accuracy: 0.7248
# Epoch 46/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.4066 - accuracy: 0.8347 - val_loss: 0.6821 - val_accuracy: 0.7604
# Epoch 47/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.3962 - accuracy: 0.8382 - val_loss: 0.6795 - val_accuracy: 0.7543
# Epoch 48/50
# 891/891 [==============================] - 8s 9ms/step - loss: 0.3707 - accuracy: 0.8516 - val_loss: 0.7517 - val_accuracy: 0.7494
# Epoch 49/50
# 891/891 [==============================] - 8s 8ms/step - loss: 0.3837 - accuracy: 0.8462 - val_loss: 0.6825 - val_accuracy: 0.7531
# Epoch 50/50
# 891/891 [==============================] - 8s 8ms/step - loss: 0.3750 - accuracy: 0.8481 - val_loss: 0.6982 - val_accuracy: 0.7457

# %% [markdown]
# Comprobamos el modelo con los datos de test.

# %%
scores = model.evaluate([x_test_num, x_test_img], y_test_class, verbose=0)
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# Loss: 0.747
# Accuracy: 0.732

# %% [markdown]
# Podemos concluir que las imágenes aportan muy poco (o nada) al modelo y que simplemente con los datos numéricos tenemos mejor precisión.
